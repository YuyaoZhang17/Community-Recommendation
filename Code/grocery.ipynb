# %%
import requests 
import json
import bs4
import urllib

# %%
url="https://opendata.dc.gov/datasets/grocery-store-locations/data"
r=requests.get(url)

# %%
r = requests.get(url, allow_redirects=True)
r.content
# Out:
# b'<!DOCTYPE html><html lang="en-us"><head><title>Grocery Store Locations</title><meta name="twitter:title" content="Grocery Store Locations"><meta property="og:title" content="Grocery Store Locations"><meta name="description" content="Large chain grocery stores in Washington, DC. This dataset contains large or national chain grocery stores which have been determined by the DC Office of Planning to be Healthy Food options."><meta name="twitter:description" content="Large chain grocery stores in Washington, DC. This dataset contains large or national chain grocery stores which have been determined by the DC Office of Planning to be Healthy Food options."><meta property="og:description" content="Large chain grocery stores in Washington, DC. This dataset contains large or national chain grocery stores which have been determined by the DC Office of Planning to be Healthy Food options."><meta name="twitter:image" content="https://www.arcgis.com/sharing/rest/content/items/1d7c9d0e3aac49c1aa
# ...
